# %%
import configuration2
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-b3b52bf6deb3>", line 1, in <module>
#     import configuration2
#
#   File "/home/jupuser/agave-model/configuration2.py", line 27
#     confBtn.on_click(confBtn_click)
#           ^
# IndentationError: expected an indented block
